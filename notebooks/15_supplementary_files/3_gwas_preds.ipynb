# %%
import anndata

# %%
ad = anndata.read_h5ad("/gstore/data/resbioai/grelu/decima/20240823/gwas_44traits/gwas_preds.h5ad")
# Out:
# /opt/conda/lib/python3.11/site-packages/anndata/_core/anndata.py:1756: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
ad.shape
# Out:
# (9207, 201)

# %%
ad.obs
# Out:
#                   variant        rsid      gene strand    label
# 0     chr10_100315722_G_A    rs603424       SCD      +     GWAS
# 1     chr10_100866753_G_T  rs61873510      SLF2      +     GWAS
# 2     chr10_101607080_A_C   rs3915773      DPCD      +     GWAS
# 3     chr10_101781259_T_G   rs2735421    KCNIP2      -     GWAS
# 4     chr10_103853420_C_A   rs7909791  SH3PXD2A      -     GWAS
# ...                   ...         ...       ...    ...      ...
# 8365    chr9_99096100_C_T   rs7034716    TGFBR1      +  Control
# 8366    chr9_99093936_T_C  rs10988702    TGFBR1      +  Control
# 8367    chr9_99093395_T_G   rs4743326    TGFBR1      +  Control
# 8368    chr9_99093288_C_T   rs4742762    TGFBR1      +  Control
# 8369    chr9_99093227_T_G  rs56794597    TGFBR1      +  Control
#
# [9207 rows x 5 columns]

# %%
ad.var
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
ad
# Out:
# AnnData object with n_obs × n_vars = 9207 × 201
#     obs: 'variant', 'rsid', 'gene', 'strand', 'label'

# %%
ad.X
# Out:
# array([[-5.9603614e-04,  4.1426690e-03,  3.4549038e-03, ...,
#          5.0083087e-03,  5.2515562e-03,  4.1781371e-03],
#        [ 4.3144962e-03,  4.0750178e-03,  1.9210180e-03, ...,
#          2.8411618e-03,  1.9788742e-03,  3.2340013e-03],
#        [-1.6978750e-03,  1.1647292e-02,  1.2657642e-03, ...,
#          1.6916364e-02,  1.6843578e-02,  2.2858770e-03],
#        ...,
#        [-5.7859602e-04,  4.8699163e-04, -2.0513136e-03, ...,
#         -1.2319443e-03, -1.1222140e-03, -2.9871051e-05],
#        [-7.6304149e-04, -1.4285012e-03, -6.8549118e-03, ...,
#         -1.4073104e-03, -2.0279819e-03, -2.1771411e-03],
#        [ 2.3637369e-04,  6.7534228e-04, -1.9060572e-03, ...,
#         -1.8930152e-05,  7.1946313e-05,  2.5847857e-04]], dtype=float32)

# %%
ad.write_h5ad("Supplementary_File_3.h5ad")
