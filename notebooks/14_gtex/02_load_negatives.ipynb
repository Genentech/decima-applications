# %% [markdown]
# ## Load and process negative GTeX SNPs from the eQTL catalog

# %%
import numpy as np
import pandas as pd
import polars as pl
import anndata
import os
import tqdm

# %matplotlib inline

# %% [markdown]
# ## Paths

# %%
eqtl_cat_path = 'https://raw.githubusercontent.com/eQTL-Catalogue/eQTL-Catalogue-resources/master/data_tables/dataset_metadata.tsv'
anndata_file = "/gstore/data/resbioai/grelu/decima/20240823/data.h5ad"
susie_file='/gstore/data/resbioai/grelu/decima/20240823/bulk_eqtl_results/susie_df.csv'
cs_vars_file='/gstore/data/resbioai/grelu/decima/20240823/bulk_eqtl_results/cs_vars.npy'
out_dir = '/gstore/data/resbioai/grelu/decima/20240823/bulk_eqtl_results/'
sumstats_dir ='/gstore/data/resbioai/grelu/decima/QTS000015/sumstats/'

# %% [markdown]
# ## Get GTeX dataset ID to tissue mapping

# %%
eqtl_meta = pd.read_table(eqtl_cat_path)
eqtl_meta = eqtl_meta[eqtl_meta.quant_method == 'ge'] # gene exp. QTLs
eqtl_meta = eqtl_meta[eqtl_meta.study_label == 'GTEx']
eqtl_meta = eqtl_meta[['dataset_id', 'sample_group']]

eqtl_meta
# Out:
#     dataset_id                     sample_group
# 115  QTD000116             adipose_subcutaneous
# 120  QTD000121                 adipose_visceral
# 125  QTD000126                    adrenal_gland
# 130  QTD000131                     artery_aorta
# 135  QTD000136                  artery_coronary
# 140  QTD000141                    artery_tibial
# 145  QTD000146                   brain_amygdala
# 150  QTD000151  brain_anterior_cingulate_cortex
# 155  QTD000156                    brain_caudate
# 160  QTD000161      brain_cerebellar_hemisphere
# 165  QTD000166                 brain_cerebellum
# 170  QTD000171                     brain_cortex
# 175  QTD000176             brain_frontal_cortex
# 180  QTD000181                brain_hippocampus
# 185  QTD000186               brain_hypothalamus
# 190  QTD000191          brain_nucleus_accumbens
# 195  QTD000196                    brain_putamen
# 200  QTD000201                brain_spinal_cord
# 205  QTD000206           brain_substantia_nigra
# 210  QTD000211                           breast
# 215  QTD000216                       fibroblast
# 220  QTD000221                              LCL
# 225  QTD000226                    colon_sigmoid
# 230  QTD000231                 colon_transverse
# 235  QTD000236                    esophagus_gej
# 240  QTD000241                 esophagus_mucosa
# 245  QTD000246             esophagus_muscularis
# 250  QTD000251           heart_atrial_appendage
# 255  QTD000256             heart_left_ventricle
# 260  QTD000261                    kidney_cortex
# 265  QTD000266                            liver
# 270  QTD000271                             lung
# 275  QTD000276             minor_salivary_gland
# 280  QTD000281                           muscle
# 285  QTD000286                     nerve_tibial
# 290  QTD000291                            ovary
# 295  QTD000296                         pancreas
# 300  QTD000301                        pituitary
# 305  QTD000306                         prostate
# 310  QTD000311             skin_not_sun_exposed
# 315  QTD000316                 skin_sun_exposed
# 320  QTD000321                  small_intestine
# 325  QTD000326                           spleen
# 330  QTD000331                          stomach
# 335  QTD000336                           testis
# 340  QTD000341                          thyroid
# 345  QTD000346                           uterus
# 350  QTD000351                           vagina
# 355  QTD000356                            blood

# %%
ct_dict = eqtl_meta.set_index('dataset_id').sample_group.to_dict()
ct_dict
# Out:
# {'QTD000116': 'adipose_subcutaneous',
#  'QTD000121': 'adipose_visceral',
#  'QTD000126': 'adrenal_gland',
#  'QTD000131': 'artery_aorta',
#  'QTD000136': 'artery_coronary',
#  'QTD000141': 'artery_tibial',
#  'QTD000146': 'brain_amygdala',
#  'QTD000151': 'brain_anterior_cingulate_cortex',
#  'QTD000156': 'brain_caudate',
#  'QTD000161': 'brain_cerebellar_hemisphere',
#  'QTD000166': 'brain_cerebellum',
#  'QTD000171': 'brain_cortex',
#  'QTD000176': 'brain_frontal_cortex',
#  'QTD000181': 'brain_hippocampus',
#  'QTD000186': 'brain_hypothalamus',
#  'QTD000191': 'brain_nucleus_accumbens',
#  'QTD000196': 'brain_putamen',
#  'QTD000201': 'brain_spinal_cord',
#  'QTD000206': 'brain_substantia_nigra',
#  'QTD000211': 'breast',
#  'QTD000216': 'fibroblast',
#  'QTD000221': 'LCL',
#  'QTD000226': 'colon_sigmoid',
#  'QTD000231': 'colon_transverse',
#  'QTD000236': 'esophagus_gej',
#  'QTD000241': 'esophagus_mucosa',
#  'QTD000246': 'esophagus_muscularis',
#  'QTD000251': 'heart_atrial_appendage',
#  'QTD000256': 'heart_left_ventricle',
#  'QTD000261': 'kidney_cortex',
#  'QTD000266': 'liver',
#  'QTD000271': 'lung',
#  'QTD000276': 'minor_salivary_gland',
#  'QTD000281': 'muscle',
#  'QTD000286': 'nerve_tibial',
#  'QTD000291': 'ovary',
#  'QTD000296': 'pancreas',
#  'QTD000301': 'pituitary',
#  'QTD000306': 'prostate',
#  'QTD000311': 'skin_not_sun_exposed',
#  'QTD000316': 'skin_sun_exposed',
#  'QTD000321': 'small_intestine',
#  'QTD000326': 'spleen',
#  'QTD000331': 'stomach',
#  'QTD000336': 'testis',
#  'QTD000341': 'thyroid',
#  'QTD000346': 'uterus',
#  'QTD000351': 'vagina',
#  'QTD000356': 'blood'}

# %% [markdown]
# ## Load decima metadata

# %%
ad = anndata.read_h5ad(anndata_file)
ensembl_id_map = ad.var[['gene_id']].reset_index().set_index('gene_id')['index'].to_dict()

# %% [markdown]
# ## Load negative variants

# %%
# for each gene, we need the interval, to exclude "unseeable" stuff
gene_to_interval_dict = {v.gene_id:{'chr':v.chrom,'start':v.start,'end':v.end} for k,v in ad.var.iterrows()}

def check_scoreability(row):
    if row['gene_id'] not in gene_to_interval_dict:
        return False
    interval = gene_to_interval_dict[row['gene_id']]
    pos = row['position']
    gene_window_start = interval['start']
    gene_window_end = interval['end']
    return (pos > gene_window_start) & (pos < gene_window_end)

# %%
susie_df = pd.read_csv(susie_file)
cs_vars = np.load(cs_vars_file)
len(cs_vars)

# %%
negvar_list = []

for ds in ct_dict.keys():
    print(ds)

    print("Loading sumstats")
    file = f'{sumstats_dir}/{ds}/{ds}.all.tsv.gz'
    negvars = pl.read_csv(file, separator="\t", 
                      schema_overrides={'chromosome':pl.String},
                      columns=(1,2,3,4,5,7,8,11,16,18),
                     )
    print(len(negvars))

    print("Filtering negatives")
    # Select common SNPs
    negvars = negvars.filter(
        (pl.col('pvalue') > 0.05) & (pl.col('type') == "SNP") & (pl.col('maf') > 0.05)) # pre-select nonsignificant
    # For the same genes as the positives
    negvars = negvars.filter(pl.col('gene_id').is_in(susie_df[susie_df.dataset == ds].gene_id))
    # Not in any credible set
    negvars = negvars.filter(~pl.col('variant').is_in(list(cs_vars)))
    # In decima interval
    negvars = negvars.filter(pl.struct(pl.all()).map_elements(check_scoreability, return_dtype=pl.Boolean))
    
    negvars = negvars.to_pandas()

    print("Filtering chromosomes")
    negvars = negvars.rename(columns={'chromosome':'chrom', 'position':'pos'})
    negvars = negvars.dropna(subset=['chrom'])
    negvars['chrom'] = ['chr' + x for x in negvars.chrom]

    print("Adding metadata")
    negvars['dataset'] = ds
    negvars['celltype'] = ct_dict[ds]

    print(len(negvars))
    negvar_list.append(negvars)

negvars = pd.concat(negvar_list)
# Out:
# QTD000116
# Loading sumstats
# 168441427
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 455807
# QTD000121
# Loading sumstats
# 167019167
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 298493
# QTD000126
# Loading sumstats
# 155295380
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 193833
# QTD000131
# Loading sumstats
# 156857426
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 302831
# QTD000136
# Loading sumstats
# 163011525
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 115800
# QTD000141
# Loading sumstats
# 156641820
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 444148
# QTD000146
# Loading sumstats
# 142903869
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 59664
# QTD000151
# Loading sumstats
# 144577410
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 93223
# QTD000156
# Loading sumstats
# 170781268
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 162185
# QTD000161
# Loading sumstats
# 146116003
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 256595
# QTD000166
# Loading sumstats
# 157845385
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 352918
# QTD000171
# Loading sumstats
# 163017375
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 176158
# QTD000176
# Loading sumstats
# 152628125
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 128443
# QTD000181
# Loading sumstats
# 157111948
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 76039
# QTD000186
# Loading sumstats
# 162109365
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 94021
# QTD000191
# Loading sumstats
# 162828702
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 140524
# QTD000196
# Loading sumstats
# 159051325
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 137139
# QTD000201
# Loading sumstats
# 145204842
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 109342
# QTD000206
# Loading sumstats
# 138787026
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 59443
# QTD000211
# Loading sumstats
# 178536669
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 231309
# QTD000216
# Loading sumstats
# 141088575
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 497598
# QTD000221
# Loading sumstats
# 123444186
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 108353
# QTD000226
# Loading sumstats
# 164902640
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 215528
# QTD000231
# Loading sumstats
# 174219786
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 262885
# QTD000236
# Loading sumstats
# 163443969
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 258348
# QTD000241
# Loading sumstats
# 156605909
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 377523
# QTD000246
# Loading sumstats
# 162128605
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 422182
# QTD000251
# Loading sumstats
# 160828411
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 281644
# QTD000256
# Loading sumstats
# 158138048
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 257032
# QTD000261
# Loading sumstats
# 129380282
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 20556
# QTD000266
# Loading sumstats
# 135974843
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 105113
# QTD000271
# Loading sumstats
# 174485591
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 331437
# QTD000276
# Loading sumstats
# 143294970
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 105038
# QTD000281
# Loading sumstats
# 139517466
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 386540
# QTD000286
# Loading sumstats
# 175982593
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 616474
# QTD000291
# Loading sumstats
# 156059575
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 114127
# QTD000296
# Loading sumstats
# 135889132
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 296178
# QTD000301
# Loading sumstats
# 163548551
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 176336
# QTD000306
# Loading sumstats
# 181343664
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 131825
# QTD000311
# Loading sumstats
# 169056504
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 359722
# QTD000316
# Loading sumstats
# 168248503
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 436253
# QTD000321
# Loading sumstats
# 161886158
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 116137
# QTD000326
# Loading sumstats
# 161166640
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 270290
# QTD000331
# Loading sumstats
# 169420757
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 195413
# QTD000336
# Loading sumstats
# 223643551
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 425272
# QTD000341
# Loading sumstats
# 176857905
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 589887
# QTD000346
# Loading sumstats
# 140173857
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 78993
# QTD000351
# Loading sumstats
# 150895092
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 54872
# QTD000356
# Loading sumstats
# 123192057
# Filtering negatives
# Filtering chromosomes
# Adding metadata
# 411795

# %% [markdown]
# ## Add gene metadata

# %%
# for each negative, compute the relpos and distance to the TSS 
negvar_dedup = negvars[['gene_id','variant','pos']].drop_duplicates()

# add gene information and calculate relative variant positions (offset)
negvar_dedup = negvar_dedup.merge(ad.var[['gene_id', 'start', 'end', 'strand', 'gene_mask_start']]).rename(
    columns={'start': 'gene_window_start', 'end': 'gene_window_end', 'strand': 'gene_strand'}) # add window information
negvar_dedup['pos_relative'] = negvar_dedup.pos - negvar_dedup.gene_window_start - 1

# use gene_end to calculate offset for - genes 
negvar_dedup.loc[negvar_dedup.gene_strand=='-', 'pos_relative'] = negvar_dedup.gene_window_end[negvar_dedup.gene_strand=='-'] - negvar_dedup.pos[negvar_dedup.gene_strand=='-']
negvar_dedup['abspos_rel_TSS'] = np.abs(negvar_dedup["pos_relative"] - negvar_dedup['gene_mask_start'])

negvars = negvars.merge(negvar_dedup[['gene_id','variant','gene_strand',"pos_relative","abspos_rel_TSS"]],
    on=['gene_id','variant'])

# %% [markdown]
# ## Add gene name from Decima metadata

# %%
negvars = negvars.drop(columns=['type'])
negvars['gene'] = negvars.gene_id.map(ensembl_id_map)
negvars.head()
# Out:
#   chrom     pos ref alt          variant       maf    pvalue          gene_id  \
# 0  chr1  502653   G   T  chr1_502653_G_T  0.065405  0.586796  ENSG00000225880
# 1  chr1  591460   T   C  chr1_591460_T_C  0.060241  0.831717  ENSG00000225880
# 2  chr1  625776   T   G  chr1_625776_T_G  0.129088  0.398739  ENSG00000225880
# 3  chr1  627983   C   T  chr1_627983_C_T  0.133391  0.339284  ENSG00000225880
# 4  chr1  632781   C   T  chr1_632781_C_T  0.149742  0.195945  ENSG00000225880
#
#            rsid    dataset              celltype gene_strand  pos_relative  \
# 0  rs1167381111  QTD000116  adipose_subcutaneous           -        488709
# 1    rs60396226  QTD000116  adipose_subcutaneous           -        399902
# 2   rs150334593  QTD000116  adipose_subcutaneous           -        365586
# 3   rs137905425  QTD000116  adipose_subcutaneous           -        363379
# 4    rs61769296  QTD000116  adipose_subcutaneous           -        358581
#
#    abspos_rel_TSS       gene
# 0          324869  LINC00115
# 1          236062  LINC00115
# 2          201746  LINC00115
# 3          199539  LINC00115
# 4          194741  LINC00115

# %% [markdown]
# ## Add credible set columns

# %%
negvars['pip'] = 0
negvars['cs_id'] = 'negative'
negvars['cs_size'] = 0
negvars.head()
# Out:
#   chrom     pos ref alt          variant       maf    pvalue          gene_id  \
# 0  chr1  502653   G   T  chr1_502653_G_T  0.065405  0.586796  ENSG00000225880
# 1  chr1  591460   T   C  chr1_591460_T_C  0.060241  0.831717  ENSG00000225880
# 2  chr1  625776   T   G  chr1_625776_T_G  0.129088  0.398739  ENSG00000225880
# 3  chr1  627983   C   T  chr1_627983_C_T  0.133391  0.339284  ENSG00000225880
# 4  chr1  632781   C   T  chr1_632781_C_T  0.149742  0.195945  ENSG00000225880
#
#            rsid    dataset              celltype gene_strand  pos_relative  \
# 0  rs1167381111  QTD000116  adipose_subcutaneous           -        488709
# 1    rs60396226  QTD000116  adipose_subcutaneous           -        399902
# 2   rs150334593  QTD000116  adipose_subcutaneous           -        365586
# 3   rs137905425  QTD000116  adipose_subcutaneous           -        363379
# 4    rs61769296  QTD000116  adipose_subcutaneous           -        358581
#
#    abspos_rel_TSS       gene  pip     cs_id  cs_size
# 0          324869  LINC00115    0  negative        0
# 1          236062  LINC00115    0  negative        0
# 2          201746  LINC00115    0  negative        0
# 3          199539  LINC00115    0  negative        0
# 4          194741  LINC00115    0  negative        0

# %% [markdown]
# ## Match to positive variants by distance

# %%
# for each positive variant, collect target_negative_n negatives wich are as close to the TSS as possible, and not yet selected for this cell-type
target_negative_n = 20
selected_vars = {}
for celltype in set(susie_df['celltype']):
    print(celltype)
    
    curr_positive_df = susie_df.query('celltype == @celltype')
    curr_negative_df = negvars.query('celltype == @celltype')
    
    selected_vars[celltype] = set()
    for _,positive in curr_positive_df.iterrows():
        negative_sub = curr_negative_df[curr_negative_df.gene_id == positive['gene_id']]
        negative_sub = negative_sub.sort_values('abspos_rel_TSS')
        i = 0
        for _,variant in negative_sub.iterrows():
            if variant['variant'] not in selected_vars[celltype]:
                selected_vars[celltype].add(variant['variant'])
                i += 1
                if i == target_negative_n:
                    break
# Out:
# brain_caudate
# adipose_subcutaneous
# heart_left_ventricle
# artery_tibial
# vagina
# brain_hypothalamus
# brain_nucleus_accumbens
# stomach
# pituitary
# pancreas
# breast
# uterus
# testis
# esophagus_mucosa
# esophagus_muscularis
# brain_amygdala
# artery_aorta
# brain_cerebellum
# colon_sigmoid
# kidney_cortex
# ovary
# fibroblast
# brain_frontal_cortex
# adipose_visceral
# heart_atrial_appendage
# nerve_tibial
# brain_cerebellar_hemisphere
# colon_transverse
# lung
# artery_coronary
# brain_cortex
# esophagus_gej
# brain_anterior_cingulate_cortex
# thyroid
# skin_sun_exposed
# brain_substantia_nigra
# blood
# small_intestine
# prostate
# skin_not_sun_exposed
# brain_putamen
# brain_spinal_cord
# adrenal_gland
# minor_salivary_gland
# spleen
# liver
# LCL
# brain_hippocampus
# muscle

# %%
negvars_reduced = pd.concat([
    negvars[negvars.variant.isin(selected_vars[celltype]) & (negvars.celltype == celltype)
        ] for celltype in selected_vars])
len(susie_df), len(negvars_reduced)
# Out:
# (19049, 523679)

# %% [markdown]
# ## Print summary stats

# %%
rows = []
for celltype in selected_vars:
    rows.append({'celltype':celltype, 
                 'pos_genes':len(set(susie_df.query('celltype == @celltype')['gene'])),
                 'pos_genes_with_neg_ct':len(set(negvars.query('celltype == @celltype')['gene']) & set(susie_df.query('celltype == @celltype')['gene'])),
                 'total_pos':len(set(susie_df.query('celltype == @celltype')['variant'])),
                 'total_matched_neg':len(set(negvars.query('celltype == @celltype').merge(susie_df.query('celltype == @celltype')['gene_id'],on='gene_id')['variant'])),
                 'reduced_matched_neg':len(selected_vars[celltype]),
                 })
    
pd.DataFrame(rows)
# Out:
#                            celltype  pos_genes  pos_genes_with_neg_ct  \
# 0                     brain_caudate        237                    237
# 1              adipose_subcutaneous        695                    695
# 2              heart_left_ventricle        364                    364
# 3                     artery_tibial        684                    684
# 4                            vagina         83                     83
# 5                brain_hypothalamus        134                    134
# 6           brain_nucleus_accumbens        203                    203
# 7                           stomach        299                    299
# 8                         pituitary        260                    260
# 9                          pancreas        421                    421
# 10                           breast        334                    334
# 11                           uterus        113                    113
# 12                           testis        645                    645
# 13                 esophagus_mucosa        588                    588
# 14             esophagus_muscularis        647                    647
# 15                   brain_amygdala         93                     93
# 16                     artery_aorta        449                    449
# 17                 brain_cerebellum        521                    521
# 18                    colon_sigmoid        325                    325
# 19                    kidney_cortex         32                     32
# 20                            ovary        155                    155
# 21                       fibroblast        771                    771
# 22             brain_frontal_cortex        190                    190
# 23                 adipose_visceral        453                    453
# 24           heart_atrial_appendage        416                    416
# 25                     nerve_tibial        945                    945
# 26      brain_cerebellar_hemisphere        377                    377
# 27                 colon_transverse        384                    384
# 28                             lung        499                    499
# 29                  artery_coronary        167                    167
# 30                     brain_cortex        264                    264
# 31                    esophagus_gej        398                    398
# 32  brain_anterior_cingulate_cortex        134                    134
# 33                          thyroid        913                    913
# 34                 skin_sun_exposed        682                    682
# 35           brain_substantia_nigra         83                     83
# 36                            blood        629                    629
# 37                  small_intestine        167                    167
# 38                         prostate        196                    196
# 39             skin_not_sun_exposed        547                    547
# 40                    brain_putamen        202                    202
# 41                brain_spinal_cord        142                    142
# 42                    adrenal_gland        286                    286
# 43             minor_salivary_gland        137                    137
# 44                           spleen        394                    394
# 45                            liver        162                    162
# 46                              LCL        148                    148
# 47                brain_hippocampus        113                    113
# 48                           muscle        597                    597
#
#     total_pos  total_matched_neg  reduced_matched_neg
# 0         245             145892                 4926
# 1         748             381142                15206
# 2         364             225530                 7620
# 3         729             371392                14887
# 4          84              51042                 1686
# 5         139              87201                 2802
# 6         207             127664                 4211
# 7         310             171579                 6342
# 8         264             161558                 5374
# 9         435             264308                 8839
# 10        353             199659                 7282
# 11        113              71988                 2318
# 12        659             362820                13467
# 13        634             328825                12853
# 14        688             352030                14065
# 15         97              56710                 1960
# 16        471             260013                 9701
# 17        523             288983                10982
# 18        338             183948                 7036
# 19         32              20425                  640
# 20        161             104110                 3269
# 21        822             412184                16804
# 22        197             116536                 3980
# 23        474             255846                 9735
# 24        435             244342                 8970
# 25       1012             478890                20967
# 26        378             220027                 7840
# 27        403             231886                 8181
# 28        526             272394                10855
# 29        170             105181                 3480
# 30        273             154969                 5543
# 31        410             229489                 8404
# 32        137              86688                 2760
# 33       1000             459133                20582
# 34        742             367595                15098
# 35         85              57097                 1760
# 36        657             339959                13701
# 37        173             107508                 3540
# 38        196             122088                 4020
# 39        580             313403                11783
# 40        208             125088                 4240
# 41        142             100582                 2940
# 42        286             168876                 5957
# 43        142              99188                 2880
# 44        407             234160                 8313
# 45        163              97222                 3360
# 46        150             100831                 3060
# 47        114              70914                 2320
# 48        645             320639                13174

# %% [markdown]
# ## Combine positive and negative variants

# %%
susie_df = pd.concat([susie_df, negvars_reduced])
len(susie_df)
# Out:
# 542728

# %%
susie_df.drop(columns=['molecular_trait_id', 'maf'], inplace=True)

# %%
susie_df.head()
# Out:
#            gene_id               cs_id             variant         rsid  \
# 0  ENSG00000079335  ENSG00000079335_L1  chr1_100353172_T_G   rs17420882
# 1  ENSG00000162631  ENSG00000162631_L1  chr1_107135646_G_C  rs115668827
# 2  ENSG00000181754  ENSG00000181754_L1  chr1_109509517_A_G    rs2570972
# 3  ENSG00000134184  ENSG00000134184_L3  chr1_109671748_C_T   rs72705222
# 4  ENSG00000134184  ENSG00000134184_L1  chr1_109675302_G_A     rs611951
#
#    cs_size       pip        pvalue      beta        se          z  ...  alt  \
# 0        4  0.928287  1.472530e-07 -0.261039  0.049038  -5.419992  ...    G
# 1        1  1.000000  2.960280e-41  1.297660  0.088815  14.796299  ...    C
# 2        1  1.000000  1.708010e-60  0.710806  0.038266  18.768437  ...    G
# 3        1  0.998111  3.595720e-06  0.523832  0.111933   4.730494  ...    T
# 4        1  1.000000  2.976550e-23 -0.803308  0.077334 -10.478578  ...    A
#
#      gene    dataset              celltype gene_window_start gene_window_end  \
# 0  CDC14A  QTD000116  adipose_subcutaneous       100181161.0     100705449.0
# 1   NTNG1  QTD000116  adipose_subcutaneous       106976167.0     107500455.0
# 2  AMIGO1  QTD000116  adipose_subcutaneous       109149290.0     109673578.0
# 3   GSTM1  QTD000116  adipose_subcutaneous       109523974.0     110048262.0
# 4   GSTM1  QTD000116  adipose_subcutaneous       109523974.0     110048262.0
#
#   gene_strand gene_mask_start pos_relative  abspos_rel_TSS
# 0           +        163840.0       172010            8170
# 1           +        163840.0       159478            4362
# 2           -        163840.0       164061             221
# 3           +        163840.0       147773           16067
# 4           +        163840.0       151327           12513
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Create VEP input file

# %%
variant_df = susie_df[['chrom', 'pos', 'ref', 'alt', 'variant', 'rsid', 'gene_id', 'gene', 'gene_strand', 'pos_relative']].drop_duplicates(subset=['gene_id','variant'])
len(variant_df)
# Out:
# 229828

# %%
variant_df.head()
# Out:
#   chrom        pos ref alt             variant         rsid          gene_id  \
# 0  chr1  100353172   T   G  chr1_100353172_T_G   rs17420882  ENSG00000079335
# 1  chr1  107135646   G   C  chr1_107135646_G_C  rs115668827  ENSG00000162631
# 2  chr1  109509517   A   G  chr1_109509517_A_G    rs2570972  ENSG00000181754
# 3  chr1  109671748   C   T  chr1_109671748_C_T   rs72705222  ENSG00000134184
# 4  chr1  109675302   G   A  chr1_109675302_G_A     rs611951  ENSG00000134184
#
#      gene gene_strand  pos_relative
# 0  CDC14A           +        172010
# 1   NTNG1           +        159478
# 2  AMIGO1           -        164061
# 3   GSTM1           +        147773
# 4   GSTM1           +        151327

# %% [markdown]
# ## Save final variants

# %%
variant_df.to_csv("variants_df.csv", index=False)
susie_df.to_csv("susie_df.csv", index=False)

# %%
len(variant_df)
# Out:
# 229828
