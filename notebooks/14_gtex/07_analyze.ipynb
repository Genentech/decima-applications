# %% [markdown]
# # Generate VEP scores for GTeX tissues

# %%
import pandas as pd
import numpy as np
import scanpy as sc
import anndata
import os

# %% [markdown]
# ## Paths

# %%
out_dir = '/gstore/data/resbioai/grelu/decima/20240823/bulk_eqtl_results'
susie_file = os.path.join(out_dir, "susie_df.csv")
decima_preds_file = os.path.join(out_dir, 'gtex_eqtl_cat_decima.h5ad')
borzoi_preds_file = os.path.join(out_dir, 'gtex_eqtl_cat_borzoi.h5ad')
gtex_sample_file = 'https://raw.githubusercontent.com/broadinstitute/gtex-v8/master/data/GTEx_Analysis_v8_RNAseq_samples.txt'

# %% [markdown]
# ## Load fine-mapping results

# %%
susie_df = pd.read_csv(susie_file)
susie_df=susie_df[['variant', 'pip', 'beta', 'gene', 'celltype', 'abspos_rel_TSS']]
print(len(susie_df))
# Out:
# 542728
# /tmp/slurmjob.7941519/ipykernel_2798534/214148563.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   susie_df = pd.read_csv(susie_file)

# %% [markdown]
# ## Label positive variants (PIP > 0.9)

# %%
susie_df['label'] = susie_df.pip > 0.9
susie_df = susie_df.drop(columns='pip')
susie_df.head(3)
# Out:
#               variant      beta    gene              celltype  abspos_rel_TSS  \
# 0  chr1_100353172_T_G -0.261039  CDC14A  adipose_subcutaneous            8170
# 1  chr1_107135646_G_C  1.297660   NTNG1  adipose_subcutaneous            4362
# 2  chr1_109509517_A_G  0.710806  AMIGO1  adipose_subcutaneous             221
#
#    label
# 0   True
# 1   True
# 2   True

# %% [markdown]
# ## Load predictions

# %%
decima_preds = sc.read(decima_preds_file)
# Only consider healthy tracks to match Gtex
decima_preds = decima_preds[:, decima_preds.var.disease.isin(['healthy', 'NA'])]
decima_preds
# Out:
# View of AnnData object with n_obs × n_vars = 229828 × 5790
#     obs: 'variant', 'gene'
#     var: 'cell_type', 'tissue', 'organ', 'disease', 'study', 'dataset', 'region', 'subregion', 'celltype_coarse', 'n_cells', 'total_counts', 'n_genes', 'size_factor', 'train_pearson', 'val_pearson', 'test_pearson'

# %%
borzoi_preds = sc.read(borzoi_preds_file)
borzoi_preds
# Out:
# AnnData object with n_obs × n_vars = 229828 × 7611
#     obs: 'variant', 'gene'
#     var: 'identifier', 'file', 'clip', 'clip_soft', 'scale', 'sum_stat', 'strand_pair', 'description'

# %% [markdown]
# ## Map GTeX tissues to decima tasks

# %%
gtex_map = {
 'adipose_subcutaneous': ('tissue', ['adipose tissue', 'subcutaneous adipose tissue']),
 'adrenal_gland': ('tissue', ['adrenal gland']),
 'artery_aorta': ('tissue', ['aorta']),
 'blood':('tissue', ['blood']),
 'brain_amygdala': ('subregion', ['Amygdala']),
 'brain_anterior_cingulate_cortex': ('subregion', ['Anterior cingulate cortex','Anterior cingulate cortex - ACC']),
 'brain_cerebellar_hemisphere': ('tissue', ['Cerebellum_Lateral hemisphere of cerebellum - CBL']),
 'brain_cerebellum': ('region', ['Cerebellum']),
 'brain_cortex': ('region', ['Cerebral cortex']),
 'brain_frontal_cortex': ('tissue',['Cerebral cortex_Frontal Cortex']),
 'brain_hippocampus': ('region',['Hippocampus']),
 'brain_hypothalamus': ('region', ['Hypothalamus']),
 'brain_nucleus_accumbens': ('subregion', ['Nucleus accumbens', 'Nucleus Accumbens - NAC']),
 'brain_putamen':('subregion', ['Putamen - Pu']),
 'brain_spinal_cord': ('region',['Spinal cord']),
 'brain_substantia_nigra': ('subregion', ['Substantia Nigra - SN','Substantia nigra']),
 'breast': ('tissue', ['breast', 'mammary gland']),
 'colon_sigmoid': ('tissue',['colon', 'sigmoid colon']),
 'colon_transverse': ('tissue',['colon', 'transverse colon']),
 'esophagus_muscularis': ('tissue',['esophagus muscularis mucosa']),
 'heart_left_ventricle': ('tissue', ['heart left ventricle']),
 'kidney_cortex': ('tissue',['cortex of kidney']),
 'liver': ('organ', ['liver']),
 'lung': ('organ', ['lung']),
 'muscle': ('tissue', ['muscle tissue', 'psoas muscle']),
 'ovary': ('tissue', ['ovary']),
 'pancreas': ('tissue', ['pancreas']),
 'prostate': ('tissue', ['prostate gland', 'peripheral zone of prostate', 'transition zone of prostate']),
 'small_intestine': ('tissue',['ileum', 'small intestine']),
 'spleen': ('organ', ['spleen']),
 'stomach': ('tissue', ['stomach']),
 'testis': ('organ', ['testis']),
 'uterus': ('organ', ['uterus']),
}

#'adipose_visceral', 'brain_caudate','esophagus_mucosa',
#'minor_salivary_gland', 'pituitary', 'heart_atrial_appendage', 
#'skin_not_sun_exposed', 'skin_sun_exposed', 'thyroid', 'vagina'

gtex_map = pd.DataFrame(gtex_map, index=['decima_col', 'decima_sel']).T.reset_index(names='tissue')
print(len(gtex_map))
gtex_map.head()
# Out:
# 33
#                  tissue decima_col  \
# 0  adipose_subcutaneous     tissue
# 1         adrenal_gland     tissue
# 2          artery_aorta     tissue
# 3                 blood     tissue
# 4        brain_amygdala  subregion
#
#                                       decima_sel
# 0  [adipose tissue, subcutaneous adipose tissue]
# 1                                [adrenal gland]
# 2                                        [aorta]
# 3                                        [blood]
# 4                                     [Amygdala]

# %% [markdown]
# ## Match these GTeX tissues to Borzoi tracks

# %%
gtex_tissues = pd.read_table(gtex_sample_file).set_index('sample_id').tissue_id.to_dict()
gtex_tissues
# Out:
# {'GTEX-1117F-0226-SM-5GZZ7': 'Adipose_Subcutaneous',
#  'GTEX-1117F-0426-SM-5EGHI': 'Muscle_Skeletal',
#  'GTEX-1117F-0526-SM-5EGHJ': 'Artery_Tibial',
#  'GTEX-1117F-0626-SM-5N9CS': 'Artery_Coronary',
#  'GTEX-1117F-0726-SM-5GIEN': 'Heart_Atrial_Appendage',
#  'GTEX-1117F-1326-SM-5EGHH': 'Adipose_Visceral_Omentum',
#  'GTEX-1117F-2426-SM-5EGGH': 'Uterus',
#  'GTEX-1117F-2526-SM-5GZY6': 'Vagina',
#  'GTEX-1117F-2826-SM-5GZXL': 'Breast_Mammary_Tissue',
#  'GTEX-1117F-2926-SM-5GZYI': 'Skin_Not_Sun_Exposed_Suprapubic',
#  'GTEX-1117F-3026-SM-5GZYU': 'Minor_Salivary_Gland',
#  'GTEX-1117F-3226-SM-5N9CT': 'Brain_Cortex',
#  'GTEX-111CU-0126-SM-5GZWZ': 'Adrenal_Gland',
#  'GTEX-111CU-0226-SM-5GZXC': 'Thyroid',
#  'GTEX-111CU-0326-SM-5GZXO': 'Lung',
#  'GTEX-111CU-0426-SM-5GZY1': 'Spleen',
#  'GTEX-111CU-0526-SM-5EGHK': 'Pancreas',
#  'GTEX-111CU-0626-SM-5EGHL': 'Esophagus_Muscularis',
#  'GTEX-111CU-0726-SM-5GZYD': 'Esophagus_Mucosa',
#  'GTEX-111CU-0826-SM-5EGIJ': 'Esophagus_Gastroesophageal_Junction',
#  'GTEX-111CU-0926-SM-5EGIK': 'Stomach',
#  'GTEX-111CU-1026-SM-5EGIL': 'Adipose_Visceral_Omentum',
#  'GTEX-111CU-1126-SM-5EGIM': 'Skin_Not_Sun_Exposed_Suprapubic',
#  'GTEX-111CU-1226-SM-5EGIN': 'Colon_Sigmoid',
#  'GTEX-111CU-1326-SM-5NQ8L': 'Small_Intestine_Terminal_Ileum',
#  'GTEX-111CU-1426-SM-5GZYP': 'Colon_Transverse',
#  'GTEX-111CU-1526-SM-5N9FS': 'Prostate',
#  'GTEX-111CU-1726-SM-5EGHM': 'Testis',
#  'GTEX-111CU-1826-SM-5GZYN': 'Adipose_Subcutaneous',
#  'GTEX-111CU-2026-SM-5GZZC': 'Muscle_Skeletal',
#  'GTEX-111CU-2226-SM-5N9G5': 'Nerve_Tibial',
#  'GTEX-111FC-0126-SM-5N9DL': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-111FC-0226-SM-5N9B8': 'Adipose_Subcutaneous',
#  'GTEX-111FC-0326-SM-5GZZ1': 'Muscle_Skeletal',
#  'GTEX-111FC-0426-SM-5N9CV': 'Artery_Tibial',
#  'GTEX-111FC-0526-SM-5GZZ8': 'Nerve_Tibial',
#  'GTEX-111FC-0626-SM-5N9CU': 'Heart_Atrial_Appendage',
#  'GTEX-111FC-0826-SM-5GZWO': 'Heart_Left_Ventricle',
#  'GTEX-111FC-1026-SM-5GZX1': 'Thyroid',
#  'GTEX-111FC-1126-SM-5GZWU': 'Lung',
#  'GTEX-111FC-1326-SM-5N9D9': 'Spleen',
#  'GTEX-111FC-1926-SM-5GZYC': 'Testis',
#  'GTEX-111FC-2026-SM-5GZYO': 'Prostate',
#  'GTEX-111FC-2526-SM-5GZXU': 'Skin_Not_Sun_Exposed_Suprapubic',
#  'GTEX-111FC-2926-SM-5GZY7': 'Minor_Salivary_Gland',
#  'GTEX-111FC-3126-SM-5GZZ2': 'Brain_Cortex',
#  'GTEX-111FC-3326-SM-5GZYV': 'Brain_Cerebellum',
#  'GTEX-111VG-0008-SM-5Q5BG': 'Cells_Cultured_fibroblasts',
#  'GTEX-111VG-0326-SM-5GZX7': 'Heart_Atrial_Appendage',
#  'GTEX-111VG-0526-SM-5N9BW': 'Thyroid',
#  'GTEX-111VG-0726-SM-5GIDC': 'Lung',
#  'GTEX-111VG-1626-SM-5EGIO': 'Skin_Not_Sun_Exposed_Suprapubic',
#  'GTEX-111VG-1926-SM-5GIDO': 'Testis',
#  'GTEX-111VG-2226-SM-5N9DU': 'Colon_Transverse',
#  'GTEX-111VG-2326-SM-5N9BK': 'Adipose_Subcutaneous',
#  'GTEX-111VG-2426-SM-5GZXD': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-111VG-2526-SM-5GZXP': 'Nerve_Tibial',
#  'GTEX-111VG-2626-SM-5GZY2': 'Muscle_Skeletal',
#  'GTEX-111YS-0006-SM-5NQBE': 'Whole_Blood',
#  'GTEX-111YS-0008-SM-5Q5BH': 'Cells_Cultured_fibroblasts',
#  'GTEX-111YS-0126-SM-5987T': 'Adrenal_Gland',
#  'GTEX-111YS-0326-SM-5GZZ3': 'Heart_Atrial_Appendage',
#  'GTEX-111YS-0426-SM-5987O': 'Heart_Left_Ventricle',
#  'GTEX-111YS-0526-SM-5GZXJ': 'Artery_Aorta',
#  'GTEX-111YS-0626-SM-5GZXV': 'Lung',
#  'GTEX-111YS-0726-SM-5GZY8': 'Thyroid',
#  'GTEX-111YS-0826-SM-5GZYK': 'Esophagus_Gastroesophageal_Junction',
#  'GTEX-111YS-0926-SM-5EGGI': 'Esophagus_Mucosa',
#  'GTEX-111YS-1026-SM-5GZYE': 'Esophagus_Muscularis',
#  'GTEX-111YS-1126-SM-5GZYQ': 'Stomach',
#  'GTEX-111YS-1226-SM-5EGGJ': 'Pancreas',
#  'GTEX-111YS-1326-SM-5EGGK': 'Adipose_Visceral_Omentum',
#  'GTEX-111YS-1426-SM-5GID8': 'Small_Intestine_Terminal_Ileum',
#  'GTEX-111YS-1526-SM-5GZYW': 'Skin_Not_Sun_Exposed_Suprapubic',
#  'GTEX-111YS-1626-SM-5GZZ9': 'Colon_Transverse',
#  'GTEX-111YS-1726-SM-5GIED': 'Prostate',
#  'GTEX-111YS-1826-SM-5GIEP': 'Colon_Sigmoid',
#  'GTEX-111YS-1926-SM-5GICC': 'Breast_Mammary_Tissue',
#  'GTEX-111YS-2026-SM-5EGGL': 'Testis',
#  'GTEX-111YS-2126-SM-5EGGM': 'Nerve_Tibial',
#  'GTEX-111YS-2226-SM-5987P': 'Artery_Tibial',
#  'GTEX-111YS-2326-SM-5987L': 'Muscle_Skeletal',
#  'GTEX-111YS-2426-SM-5GZZQ': 'Adipose_Subcutaneous',
#  'GTEX-1122O-0003-SM-5Q5DL': 'Cells_EBV-transformed_lymphocytes',
#  'GTEX-1122O-0005-SM-5O99J': 'Whole_Blood',
#  'GTEX-1122O-0008-SM-5QGR2': 'Cells_Cultured_fibroblasts',
#  'GTEX-1122O-0126-SM-5GICA': 'Lung',
#  'GTEX-1122O-0226-SM-5N9DA': 'Thyroid',
#  'GTEX-1122O-0326-SM-5H124': 'Adrenal_Gland',
#  'GTEX-1122O-0426-SM-5H12G': 'Artery_Coronary',
#  'GTEX-1122O-0526-SM-5N9DM': 'Spleen',
#  'GTEX-1122O-0626-SM-5N9B9': 'Heart_Atrial_Appendage',
#  'GTEX-1122O-0726-SM-5GIEV': 'Pancreas',
#  'GTEX-1122O-0826-SM-5GICV': 'Heart_Left_Ventricle',
#  'GTEX-1122O-0926-SM-9YFLC': 'Adipose_Visceral_Omentum',
#  'GTEX-1122O-1026-SM-9WYSF': 'Skin_Not_Sun_Exposed_Suprapubic',
#  'GTEX-1122O-1126-SM-5NQ8X': 'Artery_Aorta',
#  'GTEX-1122O-1226-SM-5H113': 'Breast_Mammary_Tissue',
#  'GTEX-1122O-1326-SM-5H11F': 'Small_Intestine_Terminal_Ileum',
#  'GTEX-1122O-1426-SM-5H11R': 'Colon_Sigmoid',
#  'GTEX-1122O-1526-SM-5N9CL': 'Colon_Transverse',
#  'GTEX-1122O-1626-SM-5N9CX': 'Esophagus_Muscularis',
#  'GTEX-1122O-1726-SM-5GICM': 'Esophagus_Mucosa',
#  'GTEX-1122O-1826-SM-5EGIP': 'Esophagus_Gastroesophageal_Junction',
#  'GTEX-1122O-1926-SM-5EGIQ': 'Stomach',
#  'GTEX-1122O-2026-SM-9YFMG': 'Adipose_Subcutaneous',
#  'GTEX-1122O-2126-SM-5EGIR': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-1122O-2326-SM-9YFL9': 'Artery_Tibial',
#  'GTEX-1122O-2426-SM-5GIDN': 'Muscle_Skeletal',
#  'GTEX-1128S-0005-SM-5P9HI': 'Whole_Blood',
#  'GTEX-1128S-0008-SM-5Q5DP': 'Cells_Cultured_fibroblasts',
#  'GTEX-1128S-0126-SM-5H12S': 'Thyroid',
#  'GTEX-1128S-0326-SM-5GZZF': 'Artery_Aorta',
#  'GTEX-1128S-0726-SM-5N9D6': 'Lung',
#  'GTEX-1128S-0826-SM-5GZZI': 'Pancreas',
#  'GTEX-1128S-0926-SM-5GZZU': 'Adipose_Visceral_Omentum',
#  'GTEX-1128S-1626-SM-5H12O': 'Colon_Transverse',
#  'GTEX-1128S-2126-SM-5H12U': 'Adipose_Subcutaneous',
#  'GTEX-1128S-2326-SM-5GZZY': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-1128S-2426-SM-5H11B': 'Muscle_Skeletal',
#  'GTEX-1128S-2526-SM-5H11N': 'Artery_Tibial',
#  'GTEX-1128S-2626-SM-5H11Z': 'Pituitary',
#  'GTEX-1128S-2726-SM-5H12C': 'Brain_Cortex',
#  'GTEX-1128S-2826-SM-5N9DI': 'Brain_Cerebellum',
#  'GTEX-113IC-0006-SM-5NQ9C': 'Whole_Blood',
#  'GTEX-113IC-0008-SM-5QGRF': 'Cells_Cultured_fibroblasts',
#  'GTEX-113IC-0126-SM-5HL6T': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-113IC-0226-SM-5HL5C': 'Adipose_Subcutaneous',
#  'GTEX-113IC-0426-SM-5HL5O': 'Artery_Tibial',
#  'GTEX-113IC-0526-SM-5HL76': 'Nerve_Tibial',
#  'GTEX-113JC-0006-SM-5O997': 'Whole_Blood',
#  'GTEX-113JC-0008-SM-5QGR6': 'Cells_Cultured_fibroblasts',
#  'GTEX-113JC-0126-SM-5EGJW': 'Thyroid',
#  'GTEX-113JC-0726-SM-5GZZR': 'Adipose_Visceral_Omentum',
#  'GTEX-113JC-0926-SM-5H114': 'Esophagus_Muscularis',
#  'GTEX-113JC-1026-SM-5H117': 'Esophagus_Gastroesophageal_Junction',
#  'GTEX-113JC-1926-SM-5N9GE': 'Vagina',
#  'GTEX-113JC-2226-SM-5EGJG': 'Uterus',
#  'GTEX-113JC-2326-SM-5EQ4E': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-113JC-2726-SM-5EGIS': 'Muscle_Skeletal',
#  'GTEX-113JC-2826-SM-5EGIT': 'Pituitary',
#  'GTEX-117XS-0005-SM-5PNU6': 'Whole_Blood',
#  'GTEX-117XS-0008-SM-5Q5DQ': 'Cells_Cultured_fibroblasts',
#  'GTEX-117XS-0426-SM-5GZZN': 'Artery_Aorta',
#  'GTEX-117XS-0526-SM-5987Q': 'Thyroid',
#  'GTEX-117XS-0726-SM-5H131': 'Heart_Atrial_Appendage',
#  'GTEX-117XS-1926-SM-5GICO': 'Breast_Mammary_Tissue',
#  'GTEX-117XS-2026-SM-5GID1': 'Testis',
#  'GTEX-117XS-2226-SM-5GIE1': 'Colon_Sigmoid',
#  'GTEX-117XS-2526-SM-5H11G': 'Muscle_Skeletal',
#  'GTEX-117XS-2726-SM-5N9BL': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX
 'Esophagus_Gastroesophageal_Junction',
#  'GTEX-11DXY-1426-SM-5N9CN': 'Esophagus_Mucosa',
#  'GTEX-11DXY-1526-SM-5H129': 'Esophagus_Muscularis',
#  'GTEX-11DXY-1626-SM-5H12L': 'Adrenal_Gland',
#  'GTEX-11DXY-2026-SM-5N9CZ': 'Colon_Sigmoid',
#  'GTEX-11DXY-2326-SM-5GICW': 'Breast_Mammary_Tissue',
#  'GTEX-11DXY-2626-SM-5GIE7': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-11DXY-2726-SM-5GID2': 'Muscle_Skeletal',
#  'GTEX-11DXY-3026-SM-5N9CB': 'Pituitary',
#  'GTEX-11DXY-3126-SM-5N9BT': 'Brain_Cerebellum',
#  'GTEX-11DXY-3226-SM-5GIDE': 'Brain_Cortex',
#  'GTEX-11DXZ-0006-SM-5LZZH': 'Whole_Blood',
#  'GTEX-11DXZ-0126-SM-5EGGY': 'Liver',
#  'GTEX-11DXZ-0226-SM-5EGGZ': 'Adrenal_Gland',
#  'GTEX-11DXZ-0326-SM-5EGH1': 'Heart_Atrial_Appendage',
#  'GTEX-11DXZ-0426-SM-5987Y': 'Artery_Aorta',
#  'GTEX-11DXZ-0526-SM-5GU7J': 'Artery_Coronary',
#  'GTEX-11DXZ-0626-SM-5GU77': 'Heart_Left_Ventricle',
#  'GTEX-11DXZ-0726-SM-5N9C4': 'Lung',
#  'GTEX-11DXZ-0926-SM-5N9CG': 'Thyroid',
#  'GTEX-11DXZ-1026-SM-5N9D5': 'Esophagus_Gastroesophageal_Junction',
#  'GTEX-11DXZ-1226-SM-5H11L': 'Esophagus_Mucosa',
#  'GTEX-11DXZ-1326-SM-5H11X': 'Small_Intestine_Terminal_Ileum',
#  'GTEX-11DXZ-1426-SM-5H12A': 'Adipose_Visceral_Omentum',
#  'GTEX-11DXZ-1626-SM-5GIDI': 'Colon_Sigmoid',
#  'GTEX-11DXZ-1726-SM-5H12M': 'Colon_Transverse',
#  'GTEX-11DXZ-1826-SM-5H12Y': 'Prostate',
#  'GTEX-11DXZ-1926-SM-5GZZL': 'Breast_Mammary_Tissue',
#  'GTEX-11DXZ-2026-SM-5987S': 'Skin_Not_Sun_Exposed_Suprapubic',
#  'GTEX-11DXZ-2126-SM-59881': 'Testis',
#  'GTEX-11DXZ-2326-SM-5EGGV': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-11DXZ-2426-SM-5N9DT': 'Muscle_Skeletal',
#  'GTEX-11DXZ-2526-SM-5N9BG': 'Nerve_Tibial',
#  'GTEX-11DXZ-2626-SM-59882': 'Artery_Tibial',
#  'GTEX-11DYG-0006-SM-5NQB2': 'Whole_Blood',
#  'GTEX-11DYG-0008-SM-5QGR5': 'Cells_Cultured_fibroblasts',
#  'GTEX-11DYG-0011-R10b-SM-DNZZO': 'Brain_Frontal_Cortex_BA9',
#  'GTEX-11DYG-0011-R11a-SM-DNZZP': 'Brain_Cerebellar_Hemisphere',
#  'GTEX-11DYG-0011-R5a-SM-DO928': 'Brain_Caudate_basal_ganglia',
#  'GTEX-11DYG-0011-R6a-SM-DO936': 'Brain_Nucleus_accumbens_basal_ganglia',
#  'GTEX-11DYG-0011-R7b-SM-EXUS6': 'Brain_Putamen_basal_ganglia',
#  'GTEX-11DYG-0011-R8a-SM-DO93F': 'Brain_Hypothalamus',
#  'GTEX-11DYG-0126-SM-59883': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-
#  'GTEX-11EMC-0926-SM-59863': 'Artery_Aorta',
#  'GTEX-11EMC-1426-SM-5N9E4': 'Colon_Sigmoid',
#  'GTEX-11EMC-1726-SM-5H11P': 'Ovary',
#  'GTEX-11EMC-1826-SM-5A5JT': 'Uterus',
#  'GTEX-11EMC-1926-SM-5A5JU': 'Vagina',
#  'GTEX-11EMC-2026-SM-5A5JV': 'Breast_Mammary_Tissue',
#  'GTEX-11EMC-2226-SM-5A5JW': 'Esophagus_Mucosa',
#  'GTEX-11EMC-2526-SM-5PNVU': 'Minor_Salivary_Gland',
#  'GTEX-11EMC-2626-SM-59864': 'Muscle_Skeletal',
#  'GTEX-11EMC-2826-SM-5PNY6': 'Adipose_Subcutaneous',
#  'GTEX-11EMC-2926-SM-5EQ4F': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-11EMC-3026-SM-5EQ4R': 'Artery_Tibial',
#  'GTEX-11EMC-3126-SM-5EGJP': 'Pituitary',
#  'GTEX-11EMC-3226-SM-5EGKW': 'Brain_Cortex',
#  'GTEX-11EMC-3326-SM-5P9JH': 'Brain_Cerebellum',
#  'GTEX-11EQ8-0006-SM-5P9HJ': 'Whole_Blood',
#  'GTEX-11EQ8-0008-SM-5Q5DJ': 'Cells_Cultured_fibroblasts',
#  'GTEX-11EQ8-0226-SM-5EQ5G': 'Adipose_Subcutaneous',
#  'GTEX-11EQ8-0426-SM-5N9DP': 'Artery_Tibial',
#  'GTEX-11EQ8-0526-SM-5N9BC': 'Muscle_Skeletal',
#  'GTEX-11EQ8-0826-SM-5N9FG': 'Thyroid',
#  'GTEX-11EQ8-0926-SM-5H12V': 'Skin_Not_Sun_Exposed_Suprapubic',
#  'GTEX-11EQ8-1326-SM-5EGJQ': 'Heart_Atrial_Appendage',
#  'GTEX-11EQ8-1426-SM-5EGJR': 'Testis',
#  'GTEX-11EQ8-2626-SM-5N9BO': 'Colon_Sigmoid',
#  'GTEX-11EQ9-0002-SM-5QGQ1': 'Cells_EBV-transformed_lymphocytes',
#  'GTEX-11EQ9-0006-SM-5LUB6': 'Whole_Blood',
#  'GTEX-11EQ9-0008-SM-5Q5DK': 'Cells_Cultured_fibroblasts',
#  'GTEX-11EQ9-0126-SM-5986I': 'Adrenal_Gland',
#  'GTEX-11EQ9-0226-SM-5A5JX': 'Lung',
#  'GTEX-11EQ9-0426-SM-5A5JY': 'Spleen',
#  'GTEX-11EQ9-0526-SM-5A5JZ': 'Liver',
#  'GTEX-11EQ9-0626-SM-5A5K1': 'Thyroid',
#  'GTEX-11EQ9-0726-SM-5A5K2': 'Esophagus_Mucosa',
#  'GTEX-11EQ9-0826-SM-5986Y': 'Esophagus_Muscularis',
#  'GTEX-11EQ9-0926-SM-5HL6I': 'Esophagus_Gastroesophageal_Junction',
#  'GTEX-11EQ9-1026-SM-5H134': 'Pancreas',
#  'GTEX-11EQ9-1126-SM-5987I': 'Adipose_Visceral_Omentum',
#  'GTEX-11EQ9-1226-SM-5987E': 'Stomach',
#  'GTEX-11EQ9-1326-SM-5985X': 'Small_Intestine_Terminal_Ileum',
#  'GTEX-11EQ9-1426-SM-5987G': 'Colon_Transverse',
#  'GTEX-11EQ9-1526-SM-5PNY7': 'Colon_Sigmoid',
#  'GTEX-11EQ9-1626-SM-5PNY8': 'Skin_Not_Sun_Exposed_Suprapubic',
#  'GTEX-11EQ9-1726-SM-5HL6U': 'Prostate',
#  'GTEX-11EQ9-1826-SM-5Q5AJ': 'Breast_Mammary_Tissue',
#  'GTEX-11EQ9-1926-SM-5PNVV': 'Testis',
#  'GTEX-11EQ9-2026-SM-5P9JI': 'Minor_Salivary_Gland',
#  'GTEX-11EQ9-2126-SM-5PNVW': 'Muscle_Skeletal',
#  'GTEX-11EQ9-2226-SM-5987H': 'Artery_Tibial',
#  'GTEX-11EQ9-2326-SM-5HL5H': 'Nerve_Tibial',
#  'GTEX-11EQ9-2426-SM-5HL5T': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-11EQ9-2526-SM-5HL66': 'Adipose_Subcutaneous',
#  'GTEX-11GS4-0006-SM-5SI9M': 'Whole_Blood',
#  'GTEX-11GS4-0008-SM-5QGRA': 'Cells_Cultured_fibroblasts',
#  'GTEX-11GS4-0011-R1a-SM-DO129': 'Brain_Hippocampus',
#  'GTEX-11GS4-0011-R2a-SM-DO942': 'Brain_Substantia_nigra',
#  'GTEX-11GS4-0226-SM-5HL77': 'Skin_Not_Sun_Exposed_Suprapubic',
#  'GTEX-11GS4-0326-SM-5N9F7': 'Artery_Aorta',
#  'GTEX-11GS4-0426-SM-5N9CD': 'Heart_Atrial_Appendage',
#  'GTEX-11GS4-0526-SM-5A5KQ': 'Heart_Left_Ventricle',
#  'GTEX-11GS4-0626-SM-5A5LC': 'Artery_Coronary',
#  'GTEX-11GS4-0826-SM-5986J': 'Thyroid',
#  'GTEX-11GS4-1026-SM-5N9DE': 'Adipose_Visceral_Omentum',
#  'GTEX-11GS4-1426-SM-5N9D2': 'Esophagus_Muscularis',
#  'GTEX-11GS4-1826-SM-5HL4T': 'Colon_Sigmoid',
#  'GTEX-11GS4-2026-SM-5N9CP': 'Testis',
#  'GTEX-11GS4-2126-SM-5A5KR': 'Breast_Mammary_Tissue',
#  'GTEX-11GS4-2326-SM-5A5KS': 'Kidney_Cortex',
#  'GTEX-11GS4-2526-SM-5A5KT': 'Muscle_Skeletal',
#  'GTEX-11GS4-2626-SM-5A5LD': 'Adipose_Subcutaneous',
#  'GTEX-11GS4-2726-SM-5A5LE': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-11GS4-2826-SM-5HL56': 'Nerve_Tibial',
#  'GTEX-11GS4-2926-SM-5A5LF': 'Artery_Tibial',
#  'GTEX-11GS4-3026-SM-5A5LG': 'Pituitary',
#  'GTEX-11GS4-3126-SM-5A5LH': 'Brain_Cortex',
#  'GTEX-11GSO-0005-SM-5O9CA': 'Whole_Blood',
#  'GTEX-11GSO-0011-R1b-SM-57WD3': 'Brain_Hippocampus',
#  'GTEX-11GSO-0011-R2a-SM-57WDF': 'Brain_Substantia_nigra',
#  'GTEX-11GSO-0011-R3b-SM-57WB2': 'Brain_Anterior_cingulate_cortex_BA24',
#  'GTEX-11GSO-0226-SM-5A5LV': 'Adipose_Visceral_Omentum',
#  'GTEX-11GSO-0626-SM-5A5LW': 'Thyroid',
#  'GTEX-11GSO-1926-SM-5A5K3': 'Breast_Mammary_Tissue',
#  'GTEX-11GSO-2326-SM-5A5LX': 'Adipose_Subcutaneous',
#  'GTEX-11GSO-2426-SM-5A5LY': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-11GSO-2526-SM-5PNVX': 'Muscle_Skeletal',
#  'GTEX-11GSO-2626-SM-5Q5AK': 'Nerve_Tibial',
#  'GTEX-11GSO-2826-SM-5HL6Q': 'Pituitary',
#  'GTEX-11GSO-2926-SM-5HL73': 'Brain_Cortex',
#  'GTEX-11GSO-3026-SM-5Q5AL': 'Brain_Cerebellum',
#  'GTEX-11GSP-0006-SM-5N9EL': 'Whole_Blood',
#  'GTEX-11GSP-0008-SM-5Q5DM': 'Cells_Cultured_fibroblasts',
#  'GTEX-11GSP-0011-R10a-SM-5NQ7J': 'Brain_Frontal_Cortex_BA9',
#  'GTEX-11GSP-0011-R11b-SM-5NQ7V': 'Brain_Cerebellar_Hemisphere',
#  'GTEX-11GSP-0011-R1a-SM-9QEJ3': 'Brain_Hippocampus',
#  'GTEX-11GSP-0011-R2b-SM-9QEGE': 'Brain_Substantia_nigra',
#  'GTEX-11GSP-0011-R3a-SM-9QEGF': 'Brain_Anterior_cingulate_cortex_BA24',
#  'GTEX-11GSP-0011-R5a-SM-57WBE': 'Brain_Caudate_basal_ganglia',
#  'GTEX-11GSP-0011-R6b-SM-57WBQ': 'Brain_Nucleus_accumbens_basal_ganglia',
#  'GTEX-11GSP-0011-R7b-SM-57WC3': 'Brain_Putamen_basal_ganglia',
#  'GTEX-11GSP-0011-R8b-SM-5NQ79': 'Brain_Hypothalamus',
#  'GTEX-11GSP-0011-R9b-SM-5NQ77': 'Brain_Spinal_cord_cervical_c-1',
#  'GTEX-11GSP-0126-SM-5A5KU': 'Thyroid',
#  'GTEX-11GSP-0226-SM-5A5KV': 'Ovary',
#  'GTEX-11GSP-0326-SM-5A5KW': 'Adrenal_Gland',
#  'GTEX-11GSP-0426-SM-5A5KX': 'Pancreas',
#  'GTEX-11GSP-0626-SM-5986T': 'Liver',
#  'GTEX-11GSP-0726-SM-5986L': 'Lung',
#  'GTEX-11GSP-0926-SM-9WYSG': 'Breast_Mammary_Tissue',
#  'GTEX-11GSP-1026-SM-9WYSH': 'Adipose_Visceral_Omentum',
#  'GTEX-11GSP-1126-SM-5A5LM': 'Artery_Aorta',
#  'GTEX-11GSP-1226-SM-5985M': 'Heart_Atrial_Appendage',
#  'GTEX-11GSP-1326-SM-5A5KY': 'Heart_Left_Ventricle',
#  'GTEX-11GSP-1626-SM-5986N': 'Colon_Transverse',
#  'GTEX-11GSP-1726-SM-5A5LI': 'Esophagus_Muscularis',
#  'GTEX-11GSP-1826-SM-5N9DQ': 'Esophagus_Mucosa',
#  'GTEX-11GSP-2126-SM-5HL5E': 'Stomach',
#  'GTEX-11GSP-2226-SM-5HL5Q': 'Vagina',
#  'GTEX-11GSP-2326-SM-5HL63': 'Skin_Not_Sun_Exposed_Suprapubic',
#  'GTEX-11GSP-2426-SM-5N9BD': 'Uterus',
#  'GTEX-11GSP-2526-SM-5N9BP': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-11GSP-2726-SM-5A5LJ': 'Muscle_Skeletal',
#  'GTEX-11GSP-2826-SM-5A5LK': 'Nerve_Tibial',
#  'GTEX-11GSP-2926-SM-5N9C2': 'Artery_Tibial',
#  'GTEX-11GSP-3026-SM-5N9CE': 'Pituitary',
#  'GTEX-11GSP-3126-SM-5A5LL': 'Brain_Cerebellum',
#  'GTEX-11GSP-3226-SM-5986O': 'Brain_Cortex',
#  'GTEX-11H98-0008-SM-5QGR8': 'Cells_Cultured_fibroblasts',
#  'GTEX-11H98-0011-R10b-SM-5NQ98': 'Brain_Frontal_Cortex_BA9',
#  'GTEX-11H98-0011-R11b-SM-5NQ6U': 'Brain_Cerebellar_Hemisphere',
#  'GTEX-11H98-0011-R5b-SM-57WCF': 'Brain_Caudate_basal_ganglia',
#  'GTEX-11H98-0011-R8a-SM-5NQ8V': 'Brain_Hypothalamus',
#  'GTEX-11H98-0126-SM-5EGHG': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-11H98-0226-SM-5NQ89': 'Adipose_Subcutaneous',
#  'GTEX-11H98-0326-SM-5HL4S': 'Muscle_Skeletal',
#  'GTEX-11H98-0426-SM-5HL55': 'Nerve_Tibial',
#  'GTEX-11I78-0001-SM-5Q5BE': 'Cells_EBV-transformed_lymphocytes',
#  'GTEX-11I78-0005-SM-5N9GB': 'Whole_Blood',
#  'GTEX-11I78-0008-SM-5Q5DI': 'Cells_Cultured_fibroblasts',
#  'GTEX-11I78-0126-SM-5HL6F': 'Lung',
#  'GTEX-11I78-0226-SM-5HL6R': 'Adipose_Visceral_Omentum',
#  'GTEX-11I78-0526-SM-5986A': 'Thyroid',
#  'GTEX-11I78-0626-SM-5A5LZ': 'Pancreas',
#  'GTEX-11I78-0726-SM-5A5M1': 'Artery_Aorta',
#  'GTEX-11I78-0826-SM-5A5K4': 'Heart_Left_Ventricle',
#  'GTEX-11I78-1026-SM-5HL74': 'Artery_Coronary',
#  'GTEX-11I78-1126-SM-5A5K5': 'Small_Intestine_Terminal_Ileum',
#  'GTEX-11I78-1226-SM-5A5K6': 'Colon_Transverse',
#  'GTEX-11I78-1326-SM-5PNY9': 'Colon_Sigmoid',
#  'GTEX-11I78-1426-SM-5PNVY': 'Esophagus_Muscularis',
#  'GTEX-11I78-1526-SM-5A5K7': 'Esophagus_Mucosa',
#  'GTEX-11I78-1726-SM-5A5M3': 'Stomach',
#  'GTEX-11I78-1826-SM-5A5M4': 'Adrenal_Gland',
#  'GTEX-11I78-1926-SM-59878': 'Ovary',
#  'GTEX-11I78-2026-SM-5987C': 'Vagina',
#  'GTEX-11I78-2126-SM-5A5K8': 'Uterus',
#  'GTEX-11I78-2226-SM-5PNYA': 'Breast_Mammary_Tissue',
#  'GTEX-11I78-2326-SM-5Q5AH': 'Artery_Tibial',
#  'GTEX-11I78-2426-SM-5A5K9': 'Muscle_Skeletal',
#  'GTEX-11I78-2626-SM-5Q5AI': 'Adipose_Subcutaneous',
#  'GTEX-11LCK-0005-SM-5O98U': 'Whole_Blood',
#  'GTEX-11LCK-0008-SM-5Q5BB': 'Cells_Cultured_fibroblasts',
#  'GTEX-11LCK-0126-SM-5A5M5': 'Spleen',
#  'GTEX-11LCK-0226-SM-5A5M6': 'Pancreas',
#  'GTEX-11LCK-0326-SM-5A5M7': 'Adipose_Visceral_Omentum',
#  'GTEX-11LCK-0426-SM-5A5M8': 'Lung',
#  'GTEX-11LCK-0526-SM-5A5M9': 'Thyroid',
#  'GTEX-11LCK-0726-SM-5PNYC': 'Artery_Aorta',
#  'GTEX-11LCK-0826-SM-5PNYD': 'Heart_Atrial_Appendage',
#  'GTEX-11LCK-0926-SM-5A5KA': 'Heart_Left_Ventricle',
#  'GTEX-11LCK-1026-SM-5A5KB': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-
 'Brain_Putamen_basal_ganglia',
#  'GTEX-11ONC-0011-R8b-SM-5NQ87': 'Brain_Hypothalamus',
#  'GTEX-11ONC-0011-R9b-SM-5NQ8J': 'Brain_Spinal_cord_cervical_c-1',
#  'GTEX-11ONC-0126-SM-5PNW6': 'Heart_Left_Ventricle',
#  'GTEX-11ONC-0526-SM-5BC57': 'Pancreas',
#  'GTEX-11ONC-0926-SM-5BC5E': 'Artery_Aorta',
#  'GTEX-11ONC-1026-SM-5GU64': 'Heart_Atrial_Appendage',
#  'GTEX-11ONC-1126-SM-5GU6G': 'Artery_Coronary',
#  'GTEX-11ONC-1426-SM-5N9F4': 'Esophagus_Muscularis',
#  'GTEX-11ONC-1526-SM-5GU6S': 'Esophagus_Mucosa',
#  'GTEX-11ONC-1926-SM-5GU75': 'Colon_Sigmoid',
#  'GTEX-11ONC-2026-SM-5HL61': 'Colon_Transverse',
#  'GTEX-11ONC-2126-SM-5HL6E': 'Breast_Mammary_Tissue',
#  'GTEX-11ONC-2226-SM-5HL6D': 'Testis',
#  'GTEX-11ONC-2326-SM-5HL6P': 'Nerve_Tibial',
#  'GTEX-11ONC-2426-SM-5GU7H': 'Muscle_Skeletal',
#  'GTEX-11ONC-2526-SM-5986W': 'Adipose_Subcutaneous',
#  'GTEX-11ONC-2726-SM-5N9DZ': 'Artery_Tibial',
#  'GTEX-11ONC-2826-SM-5P9GQ': 'Pituitary',
#  'GTEX-11ONC-2926-SM-5P9JM': 'Brain_Cortex',
#  'GTEX-11ONC-3026-SM-5985W': 'Brain_Cerebellum',
#  'GTEX-11P7K-0003-SM-5S2OU': 'Cells_EBV-transformed_lymphocytes',
#  'GTEX-11P7K-0006-SM-5N9FM': 'Whole_Blood',
#  'GTEX-11P7K-0008-SM-5S2O5': 'Cells_Cultured_fibroblasts',
#  'GTEX-11P7K-0126-SM-5986E': 'Adrenal_Gland',
#  'GTEX-11P7K-0226-SM-5986Z': 'Thyroid',
#  'GTEX-11P7K-0326-SM-59871': 'Lung',
#  'GTEX-11P7K-0426-SM-5BC5H': 'Spleen',
#  'GTEX-11P7K-0526-SM-5BC5I': 'Pancreas',
#  'GTEX-11P7K-0626-SM-5985Z': 'Prostate',
#  'GTEX-11P7K-0726-SM-5EGKX': 'Breast_Mammary_Tissue',
#  'GTEX-11P7K-0826-SM-5BC5F': 'Adipose_Visceral_Omentum',
#  'GTEX-11P7K-1026-SM-5HL6Y': 'Testis',
#  'GTEX-11P7K-1126-SM-5HL4L': 'Skin_Not_Sun_Exposed_Suprapubic',
#  'GTEX-11P7K-1226-SM-5HL4X': 'Esophagus_Muscularis',
#  'GTEX-11P7K-1326-SM-5BC5G': 'Esophagus_Mucosa',
#  'GTEX-11P7K-1426-SM-5EGKY': 'Esophagus_Gastroesophageal_Junction',
#  'GTEX-11P7K-1526-SM-5EGI7': 'Colon_Transverse',
#  'GTEX-11P7K-1626-SM-5GU63': 'Small_Intestine_Terminal_Ileum',
#  'GTEX-11P7K-1726-SM-5GU6F': 'Stomach',
#  'GTEX-11P7K-1826-SM-5HL5A': 'Colon_Sigmoid',
#  'GTEX-11P7K-1926-SM-5GU6R': 'Muscle_Skeletal',
#  'GTEX-11P7K-2026-SM-5GU74': 'Adipose_Subcutaneous',
#  'GTEX-11P7K-2126-SM-5GU7G': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-11P7K-2226-SM-5GU56': 'Nerve_Tibial',
#  'GTEX-11P7K-2326-SM-5EGKZ': 'Artery_Tibial',
#  'GTEX-11P81-0006-SM-5NQ7A': 'Whole_Blood',
#  'GTEX-11P81-0008-SM-5S2OT': 'Cells_Cultured_fibroblasts',
#  'GTEX-11P81-0126-SM-5HL5Y': 'Thyroid',
#  'GTEX-11P81-0226-SM-5HL5M': 'Lung',
#  'GTEX-11P81-0326-SM-5HL6B': 'Artery_Aorta',
#  'GTEX-11P81-0526-SM-59873': 'Heart_Atrial_Appendage',
#  'GTEX-11P81-0726-SM-5PNYH': 'Adipose_Visceral_Omentum',
#  'GTEX-11P81-0826-SM-5P9GR': 'Esophagus_Mucosa',
#  'GTEX-11P81-0926-SM-59874': 'Esophagus_Muscularis',
#  'GTEX-11P81-1026-SM-5GU54': 'Esophagus_Gastroesophageal_Junction',
#  'GTEX-11P81-1126-SM-5GU5G': 'Colon_Transverse',
#  'GTEX-11P81-1326-SM-5GU5S': 'Spleen',
#  'GTEX-11P81-1426-SM-5P9JN': 'Colon_Sigmoid',
#  'GTEX-11P81-1526-SM-5P9GS': 'Ovary',
#  'GTEX-11P81-1626-SM-5BC52': 'Uterus',
#  'GTEX-11P81-1926-SM-5BC53': 'Breast_Mammary_Tissue',
#  'GTEX-11P81-2026-SM-5P9GT': 'Minor_Salivary_Gland',
#  'GTEX-11P81-2126-SM-5HL6N': 'Vagina',
#  'GTEX-11P81-2226-SM-5PNYI': 'Skin_Not_Sun_Exposed_Suprapubic',
#  'GTEX-11P81-2326-SM-59875': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-11P81-2426-SM-5GU65': 'Adipose_Subcutaneous',
#  'GTEX-11P81-2526-SM-5GU6H': 'Muscle_Skeletal',
#  'GTEX-11P81-2626-SM-5GU6T': 'Nerve_Tibial',
#  'GTEX-11P81-2726-SM-59876': 'Artery_Tibial',
#  'GTEX-11P82-0006-SM-5N9FY': 'Whole_Blood',
#  'GTEX-11P82-0008-SM-5S2MS': 'Cells_Cultured_fibroblasts',
#  'GTEX-11P82-0126-SM-5HL72': 'Artery_Aorta',
#  'GTEX-11P82-0226-SM-5HL4O': 'Thyroid',
#  'GTEX-11P82-0326-SM-5HL51': 'Adipose_Visceral_Omentum',
#  'GTEX-11P82-0426-SM-5HL5D': 'Esophagus_Gastroesophageal_Junction',
#  'GTEX-11P82-0526-SM-5986P': 'Esophagus_Mucosa',
#  'GTEX-11P82-0626-SM-5PNYK': 'Esophagus_Muscularis',
#  'GTEX-11P82-0726-SM-5PNYL': 'Stomach',
#  'GTEX-11P82-0826-SM-5P9GU': 'Small_Intestine_Terminal_Ileum',
#  'GTEX-11P82-0926-SM-5986X': 'Minor_Salivary_Gland',
#  'GTEX-11P82-1026-SM-5BC5J': 'Colon_Transverse',
#  'GTEX-11P82-1126-SM-5BC5K': 'Prostate',
#  'GTEX-11P82-1326-SM-5HL62': 'Breast_Mammary_Tissue',
#  'GTEX-11P82-1426-SM-DTXFY': 'Skin_Not_Sun_Exposed_Suprapubic',
#  'GTEX-11P82-1526-SM-5BC5M': 'Testis',
#  'GTEX-11P82-1626-SM-59879': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-11P82-1726-SM-5Q5AT': 'Adipose_Subcutaneous',
#  'GTEX-11P82-1826-SM-5PNYJ': 'Muscle_Skeletal',
#  'GTEX-11P82-1926-SM-5Q5AU': 'Nerve_Tibial',
#  'GTEX-11PRG-0005-SM-5NQ6X': 'Whole_Blood',
#  'GTEX-11PRG-0008-SM-5S2N5': 'Cells_Cultured_fibroblasts',
#  'GTEX-11PRG-0011-R10b-SM-DO93G': 'Brain_Frontal_Cortex_BA9',
#  'GTEX-11PRG-0011-R11b-SM-DNZZY': 'Brain_Cerebellar_Hemisphere',
#  'GTEX-
 'Brain_Frontal_Cortex_BA9',
#  'GTEX-11WQC-0011-R11b-SM-57WD6': 'Brain_Cerebellar_Hemisphere',
#  'GTEX-11WQC-0011-R1b-SM-DO932': 'Brain_Hippocampus',
#  'GTEX-11WQC-0011-R2a-SM-DO927': 'Brain_Substantia_nigra',
#  'GTEX-11WQC-0011-R3a-SM-DO11T': 'Brain_Anterior_cingulate_cortex_BA24',
#  'GTEX-11WQC-0011-R5a-SM-5BC74': 'Brain_Caudate_basal_ganglia',
#  'GTEX-11WQC-0011-R6a-SM-5BC77': 'Brain_Nucleus_accumbens_basal_ganglia',
#  'GTEX-11WQC-0011-R7b-SM-5BC7A': 'Brain_Putamen_basal_ganglia',
#  'GTEX-11WQC-0011-R8b-SM-57WCH': 'Brain_Hypothalamus',
#  'GTEX-11WQC-0626-SM-5EQMF': 'Lung',
#  'GTEX-11WQC-0726-SM-5EQMR': 'Liver',
#  'GTEX-11WQC-1726-SM-5GU4W': 'Breast_Mammary_Tissue',
#  'GTEX-11WQC-1826-SM-5GU59': 'Skin_Not_Sun_Exposed_Suprapubic',
#  'GTEX-11WQC-2326-SM-5EQKE': 'Testis',
#  'GTEX-11WQC-2426-SM-5EQKQ': 'Adipose_Subcutaneous',
#  'GTEX-11WQC-2526-SM-5CVLE': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-11WQC-2626-SM-5CVLF': 'Muscle_Skeletal',
#  'GTEX-11WQC-2726-SM-5CVLG': 'Artery_Tibial',
#  'GTEX-11WQC-2826-SM-5GU7A': 'Nerve_Tibial',
#  'GTEX-11WQK-0005-SM-5O9AV': 'Whole_Blood',
#  'GTEX-11WQK-0008-SM-5SI6T': 'Cells_Cultured_fibroblasts',
#  'GTEX-11WQK-0011-R10a-SM-5BC6R': 'Brain_Frontal_Cortex_BA9',
#  'GTEX-11WQK-0011-R3b-SM-DO93K': 'Brain_Anterior_cingulate_cortex_BA24',
#  'GTEX-11WQK-0011-R8a-SM-5BC7C': 'Brain_Hypothalamus',
#  'GTEX-11WQK-0011-R9b-SM-5BC6N': 'Brain_Spinal_cord_cervical_c-1',
#  'GTEX-11WQK-0226-SM-5EQLI': 'Heart_Atrial_Appendage',
#  'GTEX-11WQK-0326-SM-5EQL1': 'Artery_Aorta',
#  'GTEX-11WQK-0526-SM-5EQLD': 'Skin_Sun_Exposed_Lower_leg',
#  'GTEX-11WQK-0726-SM-5GU71': 'Muscle_Skeletal',
#  'GTEX-11WQK-1026-SM-5EQLX': 'Skin_Not_Sun_Exposed_Suprapubic',
#  'GTEX-11WQK-1226-SM-5GU5Z': 'Lung',
#  'GTEX-11WQK-1526-SM-5EGKN': 'Adipose_Visceral_Omentum',
#  'GTEX-11WQK-1826-SM-5EQM2': 'Esophagus_Muscularis',
#  'GTEX-11WQK-2226-SM-5CVL7': 'Esophagus_Gastroesophageal_Junction',
#  'GTEX-11WQK-2426-SM-5GU5C': 'Breast_Mammary_Tissue',
#  'GTEX-11WQK-2626-SM-5EQ4K': 'Stomach',
#  'GTEX-11WQK-2726-SM-5EQMU': 'Prostate',
#  'GTEX-11WQK-2826-SM-5EQKH': 'Testis',
#  'GTEX-11WQK-2926-SM-5EQKT': 'Minor_Salivary_Gland',
#  'GTEX-11WQK-3026-SM-5EQL6': 'Brain_Cortex',
#  'GTEX-11WQK-3226-SM-5EGI3': 'Pituitary',
#  'GTEX-11XUK-0005-SM-5LU9F': 'Whole_Blood',
#  'GTEX-11XUK-0008-SM-5S2WD': 'Cells_Cultured_fibroblasts',
#  'GTEX-11XUK-0126-SM-5CVLK': 'Adrenal_Gland',
#  'GTEX-11XUK-0226-SM-5EQLW': 'Thyroid',
#  'GTEX-11XUK-0426-SM-5EQML': 'Spleen',
#  'GTEX-11XUK-0626-SM-5N9ES': 'Pancreas',
#  'GTEX-11XUK-0726-SM-5EQMX': 'Esophagus_Muscularis',
#  'GTEX-11XUK-0826-SM-5GU6P': 'Esophagus_Mucosa',
#  ...}

# %%
borzoi_gtex_samples = borzoi_preds.var[borzoi_preds.var.identifier.str.contains('GTEX')].identifier
borzoi_gtex_samples = borzoi_gtex_samples.str.split('.').apply(lambda x: x[0])
borzoi_gtex_samples.head()
# Out:
# 7522    GTEX-132QS-2526-SM-62LFJ
# 7523    GTEX-1GMR3-0826-SM-9WYT4
# 7524    GTEX-1HSEH-0226-SM-ACKVV
# 7525    GTEX-11GSP-0326-SM-5A5KW
# 7526    GTEX-13PVR-0226-SM-5RQJI
# Name: identifier, dtype: object

# %%
borzoi_map = borzoi_gtex_samples.map(gtex_tissues).reset_index().dropna().groupby('identifier').index.apply(list)

# %%
borzoi_map.index = [x.lower() for x in borzoi_map.index]

# %%
borzoi_map.index.difference(gtex_map.tissue)
# Out:
# Index(['adipose_visceral_omentum', 'artery_tibial', 'bladder',
#        'breast_mammary_tissue', 'cells_cultured_fibroblasts',
#        'cells_ebv-transformed_lymphocytes', 'cervix_ectocervix',
#        'cervix_endocervix', 'esophagus_gastroesophageal_junction',
#        'esophagus_mucosa', 'fallopian_tube', 'heart_atrial_appendage',
#        'minor_salivary_gland', 'muscle_skeletal', 'nerve_tibial', 'pituitary',
#        'skin_not_sun_exposed_suprapubic', 'skin_sun_exposed_lower_leg',
#        'small_intestine_terminal_ileum', 'thyroid', 'vagina', 'whole_blood'],
#       dtype='object')

# %%
set(gtex_map.tissue).difference(borzoi_map.index)
# Out:
# {'blood',
#  'brain_anterior_cingulate_cortex',
#  'brain_cerebellum',
#  'brain_frontal_cortex',
#  'brain_hippocampus',
#  'brain_hypothalamus',
#  'brain_nucleus_accumbens',
#  'brain_putamen',
#  'brain_spinal_cord',
#  'brain_substantia_nigra',
#  'breast',
#  'esophagus_muscularis',
#  'muscle',
#  'small_intestine'}

# %%
gtex_tissue_to_eqtl_cat_mapping = {
    'adipose_visceral_omentum':'adipose_visceral',
    'whole_blood':'blood',
    'small_intestine_terminal_ileum':'small_intestine',
    'breast_mammary_tissue':'breast',
    'muscle_skeletal':'muscle',
}

for k, v in gtex_tissue_to_eqtl_cat_mapping.items():
    borzoi_map.index = [x if x!=k else v for x in borzoi_map.index]

# %%
borzoi_map = pd.DataFrame(borzoi_map).reset_index()
borzoi_map.columns=['tissue', 'borzoi_tracks']

# %%
borzoi_map
# Out:
#                                  tissue       borzoi_tracks
# 0                  adipose_subcutaneous        [7522, 7524]
# 1                      adipose_visceral              [7523]
# 2                         adrenal_gland  [7525, 7526, 7527]
# 3                          artery_aorta              [7535]
# 4                         artery_tibial        [7534, 7536]
# 5                               bladder  [7528, 7529, 7530]
# 6                        brain_amygdala              [7540]
# 7           brain_cerebellar_hemisphere              [7539]
# 8                          brain_cortex              [7541]
# 9                                breast  [7542, 7543, 7544]
# 10           cells_cultured_fibroblasts              [7590]
# 11    cells_ebv-transformed_lymphocytes              [7531]
# 12                    cervix_ectocervix              [7547]
# 13                    cervix_endocervix        [7545, 7546]
# 14                        colon_sigmoid        [7548, 7549]
# 15                     colon_transverse              [7550]
# 16  esophagus_gastroesophageal_junction        [7551, 7552]
# 17                     esophagus_mucosa              [7553]
# 18                       fallopian_tube  [7554, 7555, 7556]
# 19               heart_atrial_appendage              [7557]
# 20                 heart_left_ventricle        [7558, 7559]
# 21                        kidney_cortex  [7560, 7561, 7562]
# 22                                liver  [7563, 7564, 7565]
# 23                                 lung  [7566, 7567, 7568]
# 24                 minor_salivary_gland  [7586, 7587, 7588]
# 25                               muscle  [7569, 7570, 7571]
# 26                         nerve_tibial        [7572, 7573]
# 27                                ovary  [7574, 7575, 7576]
# 28                             pancreas  [7577, 7578, 7579]
# 29                            pituitary  [7580, 7581, 7582]
# 30                             prostate  [7583, 7584, 7585]
# 31      skin_not_sun_exposed_suprapubic              [7589]
# 32           skin_sun_exposed_lower_leg              [7591]
# 33                      small_intestine  [7592, 7593, 7594]
# 34                               spleen  [7595, 7596, 7597]
# 35                              stomach  [7598, 7599, 7600]
# 36                               testis        [7601, 7602]
# 37                              thyroid  [7603, 7604, 7605]
# 38                               uterus        [7606, 7607]
# 39                               vagina        [7608, 7610]
# 40                                blood        [7532, 7533]

# %% [markdown]
# ## Combine decima and borzoi mappings

# %%
gtex_map = gtex_map.merge(borzoi_map, how='left')
gtex_map.head(3)
# Out:
#                  tissue decima_col  \
# 0  adipose_subcutaneous     tissue
# 1         adrenal_gland     tissue
# 2          artery_aorta     tissue
#
#                                       decima_sel       borzoi_tracks
# 0  [adipose tissue, subcutaneous adipose tissue]        [7522, 7524]
# 1                                [adrenal gland]  [7525, 7526, 7527]
# 2                                        [aorta]              [7535]

# %%
len(gtex_map), len(gtex_map.dropna(subset='borzoi_tracks'))
# Out:
# (33, 23)

# %% [markdown]
# ## Compute scores

# %%
def compute_mean_score(ad):
    return ad.X.mean(1)

def compute_weighted_score(ad):
    return np.matmul(ad.X, ad.var.n_cells)/ad.var.n_cells.sum()

# %%
decima_scores = dict()
borzoi_scores = dict()

# For each tissue
for row in gtex_map.itertuples():

    # Compute decima score
    decima_sub = decima_preds[:, decima_preds.var[row.decima_col].isin(row.decima_sel)]
    decima_scores[row.tissue] = compute_weighted_score(decima_sub)
    # Compute Borzoi score
    if isinstance(row.borzoi_tracks, list):
        borzoi_scores[row.tissue] =  compute_mean_score(borzoi_preds[:, row.borzoi_tracks])
    
decima_scores = pd.DataFrame(decima_scores)
borzoi_scores = pd.DataFrame(borzoi_scores)

decima_scores = pd.concat([decima_preds.obs.reset_index(drop=True), decima_scores], axis=1)
borzoi_scores = pd.concat([borzoi_preds.obs.reset_index(drop=True), borzoi_scores], axis=1)

# %%
decima_scores.head(2)
# Out:
#               variant    gene  adipose_subcutaneous  adrenal_gland  \
# 0  chr1_100353172_T_G  CDC14A             -0.008337      -0.003642
# 1  chr1_107135646_G_C   NTNG1              0.261189       0.398851
#
#    artery_aorta     blood  brain_amygdala  brain_anterior_cingulate_cortex  \
# 0     -0.020992 -0.012648       -0.008689                        -0.005950
# 1      0.086615  0.049476       -0.122944                        -0.331547
#
#    brain_cerebellar_hemisphere  brain_cerebellum  ...      lung    muscle  \
# 0                    -0.007069         -0.006343  ... -0.012233 -0.007603
# 1                    -0.435692         -0.282026  ...  0.190218  0.243493
#
#       ovary  pancreas  prostate  small_intestine    spleen   stomach  \
# 0 -0.002903 -0.007210 -0.008354        -0.009008 -0.011102 -0.011276
# 1  0.522173  0.247603  0.218538         0.233432  0.055801  0.110799
#
#      testis    uterus
# 0 -0.002577 -0.002820
# 1  0.369275  0.364059
#
# [2 rows x 35 columns]

# %% [markdown]
# ## Save scores

# %%
decima_scores.to_csv(
    os.path.join(out_dir, 'gtex_eqtl_cat_decima_scores.csv'),
    index=False
)
borzoi_scores.to_csv(
    os.path.join(out_dir, 'gtex_eqtl_cat_borzoi_scores.csv'),
    index=False
)

# %% [markdown]
# ## Subset susie to represented tissues

# %%
print(len(susie_df))
susie_df = susie_df[susie_df.celltype.isin(gtex_map.tissue)]
print(len(susie_df))
# Out:
# 542728
# 303417

# %% [markdown]
# ## Merge scores with fine-mapping results

# %%
decima_scores = decima_scores.melt(
    id_vars=['variant', 'gene'], var_name='celltype', value_name='decima_score'
)
borzoi_scores = borzoi_scores.melt(
    id_vars=['variant', 'gene'], var_name='celltype', value_name='borzoi_score'
)

# %%
decima_scores.head(3)
# Out:
#               variant    gene              celltype  decima_score
# 0  chr1_100353172_T_G  CDC14A  adipose_subcutaneous     -0.008337
# 1  chr1_107135646_G_C   NTNG1  adipose_subcutaneous      0.261189
# 2  chr1_109509517_A_G  AMIGO1  adipose_subcutaneous      0.068010

# %%
print(len(susie_df))
susie_df = susie_df.merge(decima_scores, on=['variant', 'gene', 'celltype'], how='left')
susie_df = susie_df.merge(borzoi_scores, on=['variant', 'gene', 'celltype'], how='left')
print(len(susie_df))
# Out:
# 303417
# 303417

# %% [markdown]
# ## Compute absolute scores

# %%
susie_df['abs_decima_score'] = np.abs(susie_df['decima_score'])
susie_df['abs_borzoi_score'] = np.abs(susie_df['borzoi_score'])

# %% [markdown]
# ## Save

# %%
susie_df.to_csv(os.path.join(out_dir, 'gtex_eqtl_cat_susie_scored.csv'),
               index=False)
