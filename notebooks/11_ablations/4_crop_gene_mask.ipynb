# %% [markdown]
# # Finetune Borzoi by cropping the output instead of including a gene mask

# %%
import anndata
import os, sys
import argparse
import wandb

sys.path.append('/code/decima/src/decima/')
from read_hdf5 import HDF5Dataset
from lightning import LightningModel

# %% [markdown]
# ## Paths

# %%
save_dir="/gstore/data/resbioai/grelu/decima/20240823/"
matrix_file = os.path.join(save_dir, "aggregated.h5ad")
h5_file = os.path.join(save_dir, "data.h5")

# %% [markdown]
# ## Load data

# %%
ad = anndata.read_h5ad(matrix_file)
train_dataset = HDF5Dataset(h5_file=h5_file, ad=ad, key="train", max_seq_shift=5000, augment_mode="random", seed=0)
val_dataset = HDF5Dataset(h5_file=h5_file, ad=ad, key="val", max_seq_shift=0)
x = train_dataset[0][0].unsqueeze(0)

# %% [markdown]
# ## Params

# %%
weight=1e-4
name=f'decima_v20240823_rep0_crop_mask' 

train_params = {
    "optimizer": "adam",
    "batch_size": 4,
    "num_workers": 16,
    "devices": 6,
    "logger": "wandb",
    "save_dir": save_dir,
    "max_epochs": 15,
    "lr":3e-5,
    "total_weight": weight,
    "accumulate_grad_batches": 5,
    "loss": 'poisson_multinomial',
    "pairs": ad.uns["disease_pairs"].values,
}
model_params = {
    "n_tasks":ad.shape[0],
    "replicate":0,
    "init_borzoi": True,
}

model = LightningModel(model_params=model_params, train_params=train_params)
model.model(x).shape

# %% [markdown]
# ## Build model

# %%
from decima_model import DecimaCropModel

# %%
model.model = DecimaCropModel(n_tasks=ad.shape[0])
model.model(x).shape

# %% [markdown]
# ## Train

# %%
wandb.login(host = "https://genentech.wandb.io")
run = wandb.init(project="decima", dir=name, name=name)

model.train_on_dataset(train_dataset, val_dataset)

train_dataset.close()
val_dataset.close()
run.finish()
